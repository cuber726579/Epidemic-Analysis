# %% [markdown]
# # 中美疫情状况分析

# %% [markdown]
# ## 环境配置

# %%
# !pip install --upgrade pyecharts
# Out:
# Requirement already satisfied: pyecharts in /opt/conda/lib/python3.6/site-packages (1.1.0)
# Collecting pyecharts
#   Downloading pyecharts-1.9.1-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 379 kB/s eta 0:00:01
# Requirement already satisfied: prettytable in /opt/conda/lib/python3.6/site-packages (from pyecharts) (0.7.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.6/site-packages (from pyecharts) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2->pyecharts) (1.1.0)
# Collecting simplejson
#   Downloading simplejson-3.17.6-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (129 kB)
#      |████████████████████████████████| 129 kB 192 kB/s eta 0:00:01
# Installing collected packages: simplejson, pyecharts
#   Attempting uninstall: pyecharts
#     Found existing installation: pyecharts 1.1.0
#     Uninstalling pyecharts-1.1.0:
#       Successfully uninstalled pyecharts-1.1.0
# Successfully installed pyecharts-1.9.1 simplejson-3.17.6
# WARNING: You are using pip version 20.3.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## 模块导入

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pyecharts import options as opts
from pyecharts.charts import Bar, Line , Timeline , Calendar
#字体设置
font = {'family': 'MicroSoft YaHei'}
matplotlib.rc("font",**font)

# %% [markdown]
# ## 读取数据

# %%
file = pd.read_csv('/home/mw/input/covid199004/owid-covid-data.csv')
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167708 entries, 0 to 167707
# Data columns (total 67 columns):
# iso_code                                      167708 non-null object
# continent                                     157674 non-null object
# location                                      167708 non-null object
# date                                          167708 non-null object
# total_cases                                   164661 non-null float64
# new_cases                                     164507 non-null float64
# new_cases_smoothed                            162519 non-null float64
# total_deaths                                  146765 non-null float64
# new_deaths                                    146799 non-null float64
# new_deaths_smoothed                           144692 non-null float64
# total_cases_per_million                       163897 non-null float64
# new_cases_per_million                         163743 non-null float64
# new_cases_smoothed_per_million                161761 non-null float64
# total_deaths_per_million                      146014 non-null float64
# new_deaths_per_million                        146048 non-null float64
# new_deaths_smoothed_per_million               143947 non-null float64
# reproduction_rate                             127163 non-null float64
# icu_patients                                  23692 non-null float64
# icu_patients_per_million                      23692 non-null float64
# hosp_patients                                 24860 non-null float64
# hosp_patients_per_million                     24860 non-null float64
# weekly_icu_admissions                         5513 non-null float64
# weekly_icu_admissions_per_million             5513 non-null float64
# weekly_hosp_admissions                        11035 non-null float64
# weekly_hosp_admissions_per_million            11035 non-null float64
# total_tests                                   70123 non-null float64
# new_tests                                     68036 non-null float64
# total_tests_per_thousand                      70123 non-null float64
# new_tests_per_thousand                        68036 non-null float64
# new_tests_smoothed                            85462 non-null float64
# new_tests_smoothed_per_thousand               85462 non-null float64
# positive_rate                                 80069 non-null float64
# tests_per_case                                79472 non-null float64
# tests_units                                   87877 non-null object
# total_vaccinations                            45566 non-null float64
# people_vaccinated                             43334 non-null float64
# people_fully_vaccinated                       40607 non-null float64
# total_boosters                                17963 non-null float64
# new_vaccinations                              37663 non-null float64
# new_vaccinations_smoothed                     85827 non-null float64
# total_vaccinations_per_hundred                45566 non-null float64
# people_vaccinated_per_hundred                 43334 non-null float64
# people_fully_vaccinated_per_hundred           40607 non-null float64
# total_boosters_per_hundred                    17963 non-null float64
# new_vaccinations_smoothed_per_million         85827 non-null float64
# new_people_vaccinated_smoothed                84489 non-null float64
# new_people_vaccinated_smoothed_per_hundred    84489 non-null float64
# stringency_index                              131217 non-null float64
# population                                    166627 non-null float64
# population_density                            149152 non-null float64
# median_age                                    138971 non-null float64
# aged_65_older                                 137465 non-null float64
# aged_70_older                                 138226 non-null float64
# gdp_per_capita                                139650 non-null float64
# extreme_poverty                               91965 non-null float64
# cardiovasc_death_rate                         137912 non-null float64
# diabetes_prevalence                           145143 non-null float64
# female_smokers                                106926 non-null float64
# male_smokers                                  105459 non-null float64
# handwashing_facilities                        69139 non-null float64
# hospital_beds_per_thousand                    124684 non-null float64
# life_expectancy                               156558 non-null float64
# human_development_index                       137387 non-null float64
# excess_mortality_cumulative_absolute          5747 non-null float64
# excess_mortality_cumulative                   5747 non-null float64
# excess_mortality                              5747 non-null float64
# excess_mortality_cumulative_per_million       5747 non-null float64
# dtypes: float64(62), object(5)
# memory usage: 85.7+ MB

# %% [markdown]
# ## 数据预处理

# %% [markdown]
# ### 我国2020-2022年每一百万人中确诊的COVID-19病例数据

# %%
chinaData = file.loc[file['location']=='China']
# chinaData.info()
dateList_china = chinaData['date']
newcaseList_china = chinaData['new_cases_smoothed_per_million']

print(dateList_china.isnull().sum())
print(newcaseList_china.isnull().sum())
# Out:
# 0
# 21

# %% [markdown]
# ### 处理缺失值

# %%
newcaseList_china.fillna(0,inplace=True)
print(newcaseList_china)

chinaData = [[i,j] for i,j in zip(dateList_china,newcaseList_china)]
# Out:
# 31791    0.000
# 31792    0.000
# 31793    0.000
# 31794    0.000
# 31795    0.000
# 31796    0.000
# 31797    0.000
# 31798    0.546
# 31799    0.740
# 31800    0.877
# 31801    1.036
# 31802    1.439
# 31803    1.665
# 31804    1.799
# 31805    2.111
# 31806    2.219
# 31807    2.403
# 31808    2.464
# 31809    2.293
# 31810    2.237
# 31811    2.042
# 31812    1.710
# 31813    2.896
# 31814    3.187
# 31815    3.123
# 31816    3.032
# 31817    2.973
# 31818    2.949
# 31819    2.952
# 31820    1.500
#          ...
# 32541    0.049
# 32542    0.056
# 32543    0.058
# 32544    0.059
# 32545    0.056
# 32546    0.055
# 32547    0.062
# 32548    0.060
# 32549    0.064
# 32550    0.077
# 32551    0.083
# 32552    0.089
# 32553    0.099
# 32554    0.108
# 32555    0.122
# 32556    0.133
# 32557    0.137
# 32558    0.146
# 32559    0.152
# 32560    0.154
# 32561    0.157
# 32562    0.164
# 32563    0.167
# 32564    0.176
# 32565    0.185
# 32566    0.197
# 32567    0.208
# 32568    0.216
# 32569    0.265
# 32570    0.282
# Name: new_cases_smoothed_per_million, Length: 780, dtype: float64
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %% [markdown]
# ### 美国2020-2022年每一百万人中确诊的COVID-19病例数据

# %%
usaData = file.loc[file['location']=='United States']
dateList_usa = usaData['date']
newcaseList_usa = usaData['new_cases_smoothed_per_million']

print(dateList_usa.isnull().sum())
print(newcaseList_usa.isnull().sum())
# Out:
# 0
# 7

# %% [markdown]
# ### 处理缺失值

# %%
newcaseList_usa.fillna(0,inplace=True)
print(newcaseList_usa)

usaData = [[i,j] for i,j in zip(dateList_usa,newcaseList_usa)]
# Out:
# 158526      0.000
# 158527      0.000
# 158528      0.000
# 158529      0.000
# 158530      0.000
# 158531      0.000
# 158532      0.000
# 158533      0.002
# 158534      0.002
# 158535      0.003
# 158536      0.003
# 158537      0.001
# 158538      0.003
# 158539      0.003
# 158540      0.002
# 158541      0.003
# 158542      0.002
# 158543      0.002
# 158544      0.002
# 158545      0.000
# 158546      0.001
# 158547      0.001
# 158548      0.001
# 158549      0.001
# 158550      0.001
# 158551      0.001
# 158552      0.001
# 158553      0.000
# 158554      0.000
# 158555      0.000
#            ...
# 159276    620.572
# 159277    558.007
# 159278    543.109
# 159279    532.287
# 159280    456.826
# 159281    412.357
# 159282    380.765
# 159283    350.879
# 159284    323.340
# 159285    314.513
# 159286    299.351
# 159287    261.958
# 159288    252.621
# 159289    239.839
# 159290    224.920
# 159291    194.586
# 159292    201.430
# 159293    198.350
# 159294    204.401
# 159295    186.200
# 159296    172.736
# 159297    165.101
# 159298    155.218
# 159299    141.426
# 159300    139.787
# 159301    125.307
# 159302    117.821
# 159303    110.900
# 159304    110.507
# 159305    110.741
# Name: new_cases_smoothed_per_million, Length: 780, dtype: float64

# %% [markdown]
# ## 图像绘制

# %% [markdown]
# ### 2020-2022年间我国每一百万人中确诊的COVID-19病例日历图

# %%
calendar_china=(
    Calendar(init_opts=opts.InitOpts(width="1600px", height="400px",theme='chalk'))
    .add(
        series_name="",
        yaxis_data=chinaData,
        calendar_opts=opts.CalendarOpts(
            pos_top="100",
            pos_left="40",
            pos_right="40",
            pos_bottom='100',
            range_=['2020-01-22', '2022-02-20'],
            yearlabel_opts=opts.CalendarYearLabelOpts(is_show=False, label_color='#D0D0D0',label_font_size=17),
            daylabel_opts=opts.CalendarDayLabelOpts(name_map="cn", label_color='#D0D0D0',label_font_size=17),
            monthlabel_opts=opts.CalendarMonthLabelOpts(name_map="cn", label_color='#D0D0D0',label_font_size=17),
        )
    )
    .set_series_opts(label_opts=opts.LabelOpts(font_size = 15))
    .set_global_opts(  
        title_opts=opts.TitleOpts(pos_top="30", pos_left="center", 
            title="2020-2022年中国每一百万人中确诊数据",
            title_textstyle_opts=opts.TextStyleOpts(font_size=25)
        ),
        visualmap_opts=opts.VisualMapOpts(  
            max_=3.2, 
            min_=0, 
            orient="horizontal", 
            is_piecewise=True,
            textstyle_opts=opts.TextStyleOpts(color="#D0D0D0",font_size=18),
        ),
        toolbox_opts=opts.ToolboxOpts()
    )
)

calendar_china.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/themes/chalk'
#         }
#     });
# </script>
#
#         <div id="c34ad5e90f1140fb8a348af142251954" style="width:1600px; height:400px;"></div>
#
# <script>
#         require(['echarts', 'chalk'], function(echarts) {
#                 var chart_c34ad5e90f1140fb8a348af142251954 = echarts.init(
#                     document.getElementById('c34ad5e90f1140fb8a348af142251954'), 'chalk', {renderer: 'canvas'});
#                 var option_c34ad5e90f1140fb8a348af142251954 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2020-01-22",
#                     0.0
#                 ],
#                 [
#                     "2020-01-23",
#                     0.0
#                 ],
#                 [
#                     "2020-01-24",
#                     0.0
#                 ],
#                 [
#                     "2020-01-25",
#                     0.0
#                 ],
#                 [
#                     "2020-01-26",
#                     0.0
#                 ],
#                 [
#                     "2020-01-27",
#                     0.0
#                 ],
#                 [
#                     "2020-01-28",
#                     0.0
#                 ],
#                 [
#                     "2020-01-29",
#                     0.546
#                 ],
#                 [
#                     "2020-01-30",
#                     0.74
#                 ],
#                 [
#                     "2020-01-31",
#                     0.877
#                 ],
#                 [
#                     "2020-02-01",
#                     1.036
#                 ],
#                 [
#                     "2020-02-02",
#                     1.439
#                 ],
#                 [
#                     "2020-02-03",
#                     1.665
#                 ],
#                 [
#                     "2020-02-04",
#                     1.7990000000000002
#                 ],
#                 [
#                     "2020-02-05",
#                     2.1109999999999998
#                 ],
#                 [
#                     "2020-02-06",
#                     2.219
#                 ],
#                 [
#                     "2020-02-07",
#                     2.403
#                 ],
#                 [
#                     "2020-02-08",
#                     2.464
#                 ],
#                 [
#                     "2020-02-09",
#                     2.293
#                 ],
#                 [
#                     "2020-02-10",
#                     2.237
#                 ],
#                 [
#                     "2020-02-11",
#                     2.042
#                 ],
#                 [
#                     "2020-02-12",
#                     1.71
#                 ],
#                 [
#                     "2020-02-13",
#                     2.8960000000000004
#                 ],
#                 [
#                     "2020-02-14",
#                     3.187
#                 ],
#                 [
#                     "2020-02-15",
#                     3.123
#                 ],
#                 [
#                     "2020-02-16",
#                     3.032
#                 ],
#                 [
#                     "2020-02-17",
#                     2.9730000000000003
#                 ],
#                 [
#                     "2020-02-18",
#                     2.949
#                 ],
#                 [
#                     "2020-02-19",
#                     2.952
#                 ],
#                 [
#                     "2020-02-20",
#                     1.5
#                 ],
#                 [
#                     "2020-02-21",
#                     0.9079999999999999
#                 ],
#                 [
#                     "2020-02-22",
#                     0.848
#                 ],
#                 [
#                     "2020-02-23",
#                     0.642
#                 ],
#                 [
#                     "2020-02-24",
#                     0.474
#                 ],
#                 [
#                     "2020-02-25",
#                     0.348
#                 ],
#                 [
#                     "2020-02-26",
#                     0.348
#                 ],
#                 [
#                     "2020-02-27",
#                     0.34600000000000003
#                 ],
#                 [
#                     "2020-02-28",
#                     0.332
#                 ],
#                 [
#                     "2020-02-29",
#                     0.23
#                 ],
#                 [
#                     "2020-03-01",
#                     0.28600000000000003
#                 ],
#                 [
#                     "2020-03-02",
#                     0.284
#                 ],
#                 [
#                     "2020-03-03",
#                     0.24600000000000002
#                 ],
#                 [
#                     "2020-03-04",
#                     0.218
#                 ],
#                 [
#                     "2020-03-05",
#                     0.19
#                 ],
#                 [
#                     "2020-03-06",
#                     0.17300000000000001
#                 ],
#                 [
#                     "2020-03-07",
#                     0.139
#                 ],
#                 [
#                     "2020-03-08",
#                     0.086
#                 ],
#                 [
#                     "2020-03-09",
#                     0.07
#                 ],
#                 [
#                     "2020-03-10",
#                     0.06
#                 ],
#                 [
#                     "2020-03-11",
#                     0.051
#                 ],
#                 [
#                     "2020-03-12",
#                     0.037000000000000005
#                 ],
#                 [
#                     "2020-03-13",
#                     0.023
#                 ],
#                 [
#                     "2020-03-14",
#                     0.017
#                 ],
#                 [
#                     "2020-03-15",
#                     0.015
#                 ],
#                 [
#                     "2020-03-16",
#                     0.013000000000000001
#                 ],
#                 [
#                     "2020-03-17",
#                     0.013000000000000001
#                 ],
#                 [
#                     "2020-03-18",
#                     0.012
#                 ],
#                 [
#                     "2020-03-19",
#                     0.013999999999999999
#                 ],
#                 [
#                     "2020-03-20",
#                     0.017
#                 ],
#                 [
#                     "2020-03-21",
#                     0.018000000000000002
#                 ],
#                 [
#                     "2020-03-22",
#                     0.024
#                 ],
#                 [
#                     "2020-03-23",
#                     0.025
#                 ],
#                 [
#                     "2020-03-24",
#                     0.028999999999999998
#                 ],
#                 [
#                     "2020-03-25",
#                     0.031
#                 ],
#                 [
#                     "2020-03-26",
#                     0.036000000000000004
#                 ],
#                 [
#                     "2020-03-27",
#                     0.036000000000000004
#                 ],
#                 [
#                     "2020-03-28",
#                     0.038
#                 ],
#                 [
#                     "2020-03-29",
#                     0.035
#                 ],
#                 [
#                     "2020-03-30",
#                     0.036000000000000004
#                 ],
#                 [
#                     "2020-03-31",
#                     0

# %% [markdown]
# ### 2020-2022年间美国每一百万人中确诊的COVID-19病例折线图

# %%
calendar_usa=(
    Calendar(init_opts=opts.InitOpts(width="1600px", height="400px",theme='chalk'))
    .add(
        series_name='',
        yaxis_data=usaData,
        calendar_opts=opts.CalendarOpts(
            pos_top="100",
            pos_left="40",
            pos_right="40",
            pos_bottom='100',
            range_=['2020-01-22', '2022-02-20'],
            yearlabel_opts=opts.CalendarYearLabelOpts(is_show=False, label_color='#D0D0D0',label_font_size=17),
            daylabel_opts=opts.CalendarDayLabelOpts(name_map="cn", label_color='#D0D0D0',label_font_size=17),
            monthlabel_opts=opts.CalendarMonthLabelOpts(name_map="cn", label_color='#D0D0D0',label_font_size=17),
        )
    )
    .set_global_opts(  
        title_opts=opts.TitleOpts(pos_top="30", pos_left="center", 
            title="2020-2022年美国确诊数据",
            title_textstyle_opts=opts.TextStyleOpts(font_size=25)
        ),
        visualmap_opts=opts.VisualMapOpts(  
            max_=800, 
            min_=0, 
            orient="horizontal", 
            is_piecewise=False,
            textstyle_opts=opts.TextStyleOpts(color="#D0D0D0",font_size=18),
        ),
        toolbox_opts=opts.ToolboxOpts(),
    )
)

calendar_usa.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/themes/chalk'
#         }
#     });
# </script>
#
#         <div id="11b792ba7d5d43abaa56ddf6c5002954" style="width:1600px; height:400px;"></div>
#
# <script>
#         require(['echarts', 'chalk'], function(echarts) {
#                 var chart_11b792ba7d5d43abaa56ddf6c5002954 = echarts.init(
#                     document.getElementById('11b792ba7d5d43abaa56ddf6c5002954'), 'chalk', {renderer: 'canvas'});
#                 var option_11b792ba7d5d43abaa56ddf6c5002954 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2020-01-22",
#                     0.0
#                 ],
#                 [
#                     "2020-01-23",
#                     0.0
#                 ],
#                 [
#                     "2020-01-24",
#                     0.0
#                 ],
#                 [
#                     "2020-01-25",
#                     0.0
#                 ],
#                 [
#                     "2020-01-26",
#                     0.0
#                 ],
#                 [
#                     "2020-01-27",
#                     0.0
#                 ],
#                 [
#                     "2020-01-28",
#                     0.0
#                 ],
#                 [
#                     "2020-01-29",
#                     0.002
#                 ],
#                 [
#                     "2020-01-30",
#                     0.002
#                 ],
#                 [
#                     "2020-01-31",
#                     0.003
#                 ],
#                 [
#                     "2020-02-01",
#                     0.003
#                 ],
#                 [
#                     "2020-02-02",
#                     0.001
#                 ],
#                 [
#                     "2020-02-03",
#                     0.003
#                 ],
#                 [
#                     "2020-02-04",
#                     0.003
#                 ],
#                 [
#                     "2020-02-05",
#                     0.002
#                 ],
#                 [
#                     "2020-02-06",
#                     0.003
#                 ],
#                 [
#                     "2020-02-07",
#                     0.002
#                 ],
#                 [
#                     "2020-02-08",
#                     0.002
#                 ],
#                 [
#                     "2020-02-09",
#                     0.002
#                 ],
#                 [
#                     "2020-02-10",
#                     0.0
#                 ],
#                 [
#                     "2020-02-11",
#                     0.001
#                 ],
#                 [
#                     "2020-02-12",
#                     0.001
#                 ],
#                 [
#                     "2020-02-13",
#                     0.001
#                 ],
#                 [
#                     "2020-02-14",
#                     0.001
#                 ],
#                 [
#                     "2020-02-15",
#                     0.001
#                 ],
#                 [
#                     "2020-02-16",
#                     0.001
#                 ],
#                 [
#                     "2020-02-17",
#                     0.001
#                 ],
#                 [
#                     "2020-02-18",
#                     0.0
#                 ],
#                 [
#                     "2020-02-19",
#                     0.0
#                 ],
#                 [
#                     "2020-02-20",
#                     0.0
#                 ],
#                 [
#                     "2020-02-21",
#                     0.001
#                 ],
#                 [
#                     "2020-02-22",
#                     0.001
#                 ],
#                 [
#                     "2020-02-23",
#                     0.001
#                 ],
#                 [
#                     "2020-02-24",
#                     0.001
#                 ],
#                 [
#                     "2020-02-25",
#                     0.001
#                 ],
#                 [
#                     "2020-02-26",
#                     0.001
#                 ],
#                 [
#                     "2020-02-27",
#                     0.001
#                 ],
#                 [
#                     "2020-02-28",
#                     0.0
#                 ],
#                 [
#                     "2020-02-29",
#                     0.004
#                 ],
#                 [
#                     "2020-03-01",
#                     0.006999999999999999
#                 ],
#                 [
#                     "2020-03-02",
#                     0.017
#                 ],
#                 [
#                     "2020-03-03",
#                     0.025
#                 ],
#                 [
#                     "2020-03-04",
#                     0.039
#                 ],
#                 [
#                     "2020-03-05",
#                     0.07200000000000001
#                 ],
#                 [
#                     "2020-03-06",
#                     0.094
#                 ],
#                 [
#                     "2020-03-07",
#                     0.162
#                 ],
#                 [
#                     "2020-03-08",
#                     0.209
#                 ],
#                 [
#                     "2020-03-09",
#                     0.231
#                 ],
#                 [
#                     "2020-03-10",
#                     0.304
#                 ],
#                 [
#                     "2020-03-11",
#                     0.446
#                 ],
#                 [
#                     "2020-03-12",
#                     0.602
#                 ],
#                 [
#                     "2020-03-13",
#                     0.85
#                 ],
#                 [
#                     "2020-03-14",
#                     1.105
#                 ],
#                 [
#                     "2020-03-15",
#                     1.156
#                 ],
#                 [
#                     "2020-03-16",
#                     1.7530000000000001
#                 ],
#                 [
#                     "2020-03-17",
#                     2.459
#                 ],
#                 [
#                     "2020-03-18",
#                     3.4419999999999997
#                 ],
#                 [
#                     "2020-03-19",
#                     5.182
#                 ],
#                 [
#                     "2020-03-20",
#                     7.643
#                 ],
#                 [
#                     "2020-03-21",
#                     9.89
#                 ],
#                 [
#                     "2020-03-22",
#                     13.617
#                 ],
#                 [
#                     "2020-03-23",
#                     17.772000000000002
#                 ],
#                 [
#                     "2020-03-24",
#                     21.541999999999998
#                 ],
#                 [
#                     "2020-03-25",
#                     25.605999999999998
#                 ],
#                 [
#                     "2020-03-26",
#                     31.325
#                 ],
#                 [
#                     "2020-03-27",
#                     36.57
#                 ],
#                 [
#                     "2020-03-28",
#                     43.508
#                 ],
#                 [
#                     "2020-03-29",
#                     46.601000000000006
#                 ],
#                 [
#                     "2020-03-30",
#                     51.321999999999996
#                 ],
#                 [
#                     "2020-03-31",
#                     58.086000000000006
#                 ],
#                 [
#                     "2020-04-01",
#                     66.252
#                 ],
